# %%
from matplotlib import pyplot as plt
from utils.environments import NRoomsZanin
env = NRoomsZanin(room_shapes=(8, 8), grid_shape=(1,2), n_doors=2)
env.render()
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
for action in "URRRRRRRRRRRRRR":
    print(action)
    state, reward, truncated, terminated, info = env.step(action)
    print(reward)
    env.render()
    plt.show()
# Out:
# U
# 0.0
# R
# 0.0
# R
# 0.0
# R
# 0.0
# R
# 0.0
# R
# 0.0
# R
# 1.0
# R
# -0.1
# R
# -0.1
# R
# -0.1
# R
# -0.1
# R
# -0.1
# R
# -0.1
# R
# -0.1
# R
# -0.1
