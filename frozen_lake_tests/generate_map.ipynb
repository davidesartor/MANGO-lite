# %%
import sys
sys.path.append("..")
from mango.environments import frozen_lake
from utils_sim import env_params

map_scale = 4
p_frozen = 0.5
env_params = env_params(map_scale, p_frozen, seed=0)
env = frozen_lake.CustomFrozenLakeEnv(**env_params)
env = frozen_lake.wrappers.ReInitOnReset(env, **env_params)
for i in range(3):
    env.reset()
    frozen_lake.plot_utils.plot_map(env)
