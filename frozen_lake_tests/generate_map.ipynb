# %%
import sys
sys.path.append("..")
from mango.environments import frozen_lake
from mango import Mango
from utils_sim import env_params

map_scale = 4
p_frozen = 0.5
for i in range(10):
    env = frozen_lake.CustomFrozenLakeEnv(**env_params(map_scale, p_frozen)) #type: ignore
    option_manager = Mango(env, [], dict()) #type: ignore
    frozen_lake.plot_utils.plot_all_abstractions(option_manager)
