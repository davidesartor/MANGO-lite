# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
import maps

# %%
key = jax.random.PRNGKey(0)
frozen = jax.random.uniform(key, (16, 16)) > 0.5
plt.imshow(frozen, cmap="gray", vmin=0, vmax=1)
print(maps.is_connected(frozen))
# %timeit maps.is_connected(frozen).block_until_ready()
# Out:
# False
# 151 µs ± 5.74 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
key = jax.random.PRNGKey(42)
map = maps.generate_map(key, (8, 8), 0.5)
plt.imshow(map, cmap="gray", vmin=0, vmax=1)
plt.show()

# %timeit maps.generate_map(key, (8, 8), 0.5).block_until_ready()
# Out:
# 263 ms ± 1.61 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
